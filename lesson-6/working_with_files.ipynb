# %% [markdown]
# ### Working with Files
#     - Open files
#     - Read files
#     - Write files
#     - Append to files

# %% [markdown]
# #### The open() Function
#
# |Character | Meaning|
# | --- | --- |
# |‘r’ | open file for reading (default)|
# |‘w’ | open for writing. If file exists, replace its contents|
# |‘a’ | open for writing. If file exists, appends to end|
# |‘b’ | binary mode|
# |‘t’ | text mode (default)|
# |’+’ | reading and writing|

# %% [markdown]
# **reading**
# ```python
# file_handler = open('example.txt')
# # do something with the file
# file_handler.close()
# ```

# %% [markdown]
# **using `finally`**
# ```python
# try:
#     file_handler = open('example.txt')
# except:
#     # ignore the error, print a warning, or log the exception
#     pass
# finally:
#     file_handler.close()
# ```

# %%
file = open('sample.txt', mode='w')
file.write('banana')
file.close()

# %%
file = open('sample.txt')
a = file.read()
# Out:
# banana

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# **using context manager**
# ```python
# with open('example.txt') as file_handler:
#     # do something with the handler here
#     data = file_handler.read()
# ```

# %%
with open('sample.txt') as f:
    txt = f.read()

f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 4
#       1 with open('sample.txt') as f:
#       2     txt = f.read()
# ----> 4 f.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# **reading examples:**

# %%
with open('sample.txt') as f:
    txt = f.readline()
    print(txt)
    txt = f.readline()
    print(txt)
# Out:
# Python is an interpreted, object-oriented, high-level programming
#
# language with dynamic semantics. Its high-level built

# %%
with open('sample.txt') as f:
    print(f.readlines())
# Out:
# ['Python is an interpreted, object-oriented, high-level programming\n', 'language with dynamic semantics. Its high-level built\n', 'in data structures, combined ']

# %%
with open('sample.txt') as f:
    for line in f:
        print(line, end='')
# Out:
# Python is an interpreted, object-oriented, high-level programming
# language with dynamic semantics. Its high-level built
# in data structures, combined

# %%
with open('example.txt') as file_handler:
    lines = file_handler.readlines()
    for line in lines:
        print(line)

# %%
with open('sample.txt') as file_handler:
    file_contents = file_handler.read(50)
    print(file_contents)
# Out:
# Python is an interpreted, object-oriented, high-le

# %%
f = open('sample.txt')
txt1 = f.read()
print(txt1)
# Out:
# Python is an interpreted, object-oriented, high-level programming
# language with dynamic semantics. Its high-level built
# in data structures, combined

# %%
txt2 = f.read()
print(txt2)

# %%
while True:
    with open('example.txt') as file_handler:
        data = file_handler.read(1024)
        if not data:
            break
        print(data)

# %%
with open('example.pdf', 'rb') as file_handler:
    file_contents = file_handler.read()

# %% [markdown]
# **writing examples:**

# %%
with open('example.txt', 'w') as file_handler:
    file_handler.write('This is a test')

# %%
with open('example.txt') as file_handler:
    print(file_handler.read())

# %% [markdown]
# **appending examples:**

# %%
with open('example.txt', 'a') as file_handler:
    file_handler.write('Here is some more text')

# %% [markdown]
# **catching file exceptions:**

# %%
try:
    with open('example.txt') as file_handler:
        for line in file_handler:
            print(line)
except OSError:
    print('An error has occurred')

# %% [markdown]
# #### Seeking Within a File
#
# The `seek()` method accepts two arguments:
# - offset - A number of bytes from whence
# - whence - The reference point
#
# You can set `whence` to one of these three values:
# - 0 - The beginning of the file (default)
# - 1 - The current file position
# - 2 - The end of the file
#
# > Note: We cannot set the point of reference 1 or 2 when a file is opened in text mode, but we can specify 1 or 2 when the offset is set to 0.

# %%
f = open('sample.txt')
f.tell()
f.read(5)
f.tell()
f.read()
# Out:
# 'n is an interpreted, object-oriented, high-level programming\nlanguage with dynamic semantics. Its high-level built\nin data structures, combined '

# %%
f.tell()
# Out:
# 151

# %%
f.seek(0)
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# 'Python is an interpreted, object-oriented, high-level programming\nlanguage with dynamic semantics. Its high-level built\nin data structures, combined '

# %%
with open('sample.txt', 'rb') as file:
    # Setting cursor at the 100th pos
    file.seek(100)
    print(f'File cursor position before: {file.tell()}')
    # Moving back 15 chars from the current position
    file.seek(-15, 1)
    # Using tell() function
    pos = file.tell()
    # Printing the position of the cursor
    print(f'File cursor position now: {pos}')
    # Printing the content
    data = file.read()
    print(data)

# %%
f = open('demo.txt', 'wt')

# %%
f.write('Demo text')
# Out:
# 9

# %%
f.close()

# %%
f = open('sample.txt', 'rb')
txt = f.read()

# %%
type(txt)
# Out:
# bytes

# %%
print(txt)
# Out:
# b'Python is an interpreted, object-oriented, high-level programming\r\nlanguage with dynamic semantics. Its high-level built\r\nin data structures, combined '

# %%
str(txt)
# Out:
# "b'Python is an interpreted, object-oriented, high-level programming\\r\\nlanguage with dynamic semantics. Its high-level built\\r\\nin data structures, combined '"

# %%
print(txt.decode('utf-8'))
# Out:
# Python is an interpreted, object-oriented, high-level programming
# language with dynamic semantics. Its high-level built
# in data structures, combined

# %%
import requests

url = 'https://media.istockphoto.com/id/483724081/photo/yosemite-valley-landscape-and-river-california.jpg?s=612x612&w=0&k=20&c=QQ7rvq0Qbfpkug1Wbd36PGqkOntoPFKWxiE4w4tV-NE='
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
content = res.content
type(content)
# Out:
# bytes

# %%
content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xe1\x00rExif\x00\x00II*\x00\x08\x00\x00\x00\x04\x00\x0e\x01\x02\x00\x14\x00\x00\x00>\x00\x00\x00\x98\x82\x02\x00\x08\x00\x00\x00R\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00Z\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00b\x00\x00\x00\x00\x00\x00\x00Yosemite Valley viewzodebala,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00\xff\xe1\x05\x97http://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:x="adobe:ns:meta/">\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n\t\t<rdf:Description rdf:about="" xmlns:photoshop="http://ns.adobe.com/photoshop/1.0/" xmlns:Iptc4xmpCore="http://iptc.org/std/Iptc4xmpCore/1.0/xmlns/"   xmlns:GettyImagesGIFT="http://xmp.gettyimages.com/gift/1.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:plus="http://ns.useplus.org/ldf/xmp/1.0/"  xmlns:iptcExt="http://iptc.org/std/Iptc4xmpExt/2008-02-29/" xmlns:xmpRights="http://ns.adobe.com/xap/1.0/rights/" dc:Rights="zodebala" photoshop:Credit="Getty Images" GettyImagesGIFT:AssetID="483724081" xmpRights:WebStatement="https://www.istockphoto.com/legal/license-agreement?utm_medium=organic&amp;utm_source=google&amp;utm_campaign=iptcurl" plus:DataMining="http://ns.useplus.org/ldf/vocab/DMI-PROHIBITED-EXCEPTSEARCHENGINEINDEXING" >\n<dc:creator><rdf:Seq><rdf:li>zodebala</rdf:li></rdf:Seq></dc:creator><dc:description><rdf:Alt><rdf:li xml:lang="x-default">Yosemite Valley view</rdf:li></rdf:Alt></dc:description>\n<plus:Licensor><rdf:Seq><rdf:li rdf:parseType=\'Resource\'><plus:LicensorURL>https://www.istockphoto.com/photo/license-gm483724081-?utm_medium=organic&amp;utm_source=google&amp;utm_campaign=iptcurl</plus:LicensorURL></rdf:li></rdf:Seq></plus:Licensor>\n\t\t</rdf:Description>\n\t</rdf:RDF>\n</x:xmpmeta>\n<?xpacket end="w"?>\n\xff\xed\x00`Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x